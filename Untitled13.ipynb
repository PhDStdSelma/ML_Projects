# %% [markdown]
# <a href="https://colab.research.google.com/github/PhDStdSelma/ML_Projects/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import pandas as pd
url="/content/drive/MyDrive/housing.csv"
df=pd.read_csv(url)
df.head()
# Out:
#    Avg. Area Income  ...                                            Address
# 0      79545.458574  ...  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1      79248.642455  ...  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2      61287.067179  ...  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3      63345.240046  ...                          USS Barnett\nFPO AP 44820
# 4      59982.197226  ...                         USNS Raymond\nFPO AE 09386
#
# [5 rows x 7 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of       Avg. Area Income  ...                                            Address
# 0         79545.458574  ...  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1         79248.642455  ...  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2         61287.067179  ...  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3         63345.240046  ...                          USS Barnett\nFPO AP 44820
# 4         59982.197226  ...                         USNS Raymond\nFPO AE 09386
# ...                ...  ...                                                ...
# 4995      60567.944140  ...                   USNS Williams\nFPO AP 30153-7653
# 4996      78491.275435  ...              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997      63390.686886  ...  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998      68001.331235  ...                          USS Wallace\nFPO AE 73316
# ...

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  ...  Area Population         Price
# count       5000.000000          5000.000000  ...      5000.000000  5.000000e+03
# mean       68583.108984             5.977222  ...     36163.516039  1.232073e+06
# std        10657.991214             0.991456  ...      9925.650114  3.531176e+05
# min        17796.631190             2.644304  ...       172.610686  1.593866e+04
# 25%        61480.562388             5.322283  ...     29403.928702  9.975771e+05
# 50%        68804.286404             5.970429  ...     36199.406689  1.232669e+06
# 75%        75783.338666             6.650808  ...     42861.290769  1.471210e+06
# max       107701.748378             9.519088  ...     69621.713378  2.469066e+06
#
# [8 rows x 6 columns]

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.heatmap(df.corr(), cmap='RdYlBu', square=True)

# %%
y=df['Price']

# %%
plt.scatter(df['Avg. Area Number of Rooms'],df['Price'])
plt.xlabel("   ")
plt.ylabel("   ")
plt.title("Price Vs. Average Number of Rooms")
plt.show()

# %%
sns.lmplot(x = "Avg. Area Number of Rooms", y = "Price", data = df)

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
lm_reg = linear_model.LinearRegression()

X = df['Avg. Area Number of Rooms']
y = df['Price']
y_reshaped = np.array(y).reshape(-1, 1)
X_reshaped = np.array(X).reshape(-1, 1)
print("Dimensions of y after reshaping: ", y_reshaped.shape)
print("Dimensions of X after reshaping: ", X_reshaped.shape)
lm_reg.fit(X_reshaped, y_reshaped)
print('The intercept of simple linear regression is', lm_reg.intercept_)
print('The intercept of simple linear regression is', lm_reg.coef_)
y_pred = lm_reg.predict(X_reshaped)
# Out:
# Dimensions of y after reshaping:  (5000, 1)
# Dimensions of X after reshaping:  (5000, 1)
# The intercept of simple linear regression is [408619.81940216]
# The intercept of simple linear regression is [[117841.63757442]]

# %%
plt.scatter(X, y, color='blue', alpha=0.5)
plt.plot(X_reshaped, y_pred, color='red', linewidth=3)
plt.show()
